# %%
import jax.numpy as jnp
from jax import random, grad, jit
from jax.scipy.linalg import inv, svd, eigh, det
from jax_models import visualize_observations, Lorenz96, generate_true_states, generate_gc_localization_matrix
from jax_filters import ensrf_steps, kalman_filter_process

from jax.lax import scan
import jax
from scipy.linalg import solve_discrete_are
from tqdm import tqdm
import matplotlib.pyplot as plt
from jax.tree_util import Partial


key = random.PRNGKey(3)

# System dimensions
n = 10  # System dimension
p = 2  # Observation dimension
num_steps = 100 # number of steps
J0 = 0 # burn in period
N = 10 # Monte Carlo samples

def create_stable_matrix(n, key):
    # Generate a symmetric random matrix
    A = random.normal(key, (n, n))
    A = (A + A.T) / 2
    
    # Ensure the matrix has a spectral radius < 1 for stability
    eigenvalues, eigenvectors = eigh(A)
    scaled_eigenvalues = eigenvalues / (jnp.abs(eigenvalues).max() + 0.1)  # Scale eigenvalues to ensure stability
    A_stable = eigenvectors @ jnp.diag(scaled_eigenvalues) @ eigenvectors.T
    
    return A_stable

# Model parameters
m0 = jnp.ones((n,))
C0 = jnp.eye(n) * 1.0   # Initial state covariance matrix (P)
Q = jnp.eye(n) * 0.5    # Process noise covariance matrix (Sigma in Julia code)
R = jnp.eye(n) * 1.0    # Observation noise covariance matrix (Gamma)
inv_R = inv(R)
M = create_stable_matrix(n,key)    # State transition matrix (A)
H = jnp.eye(n)          # Observation matrix
observation_interval = 1
n_ensemble = 30

# State initialization
vd0 = m0 + random.multivariate_normal(key, jnp.zeros(n), C0)

initial_state = vd0
key, _ = random.split(key)


def state_transition_function(x):
    return jnp.dot(M, x)

def jacobian_function(x):
    return M

jac_func = Partial(jacobian_function)
A_step = Partial(state_transition_function)


observations, true_states = generate_true_states(key, num_steps, n, vd0, H, Q, R, A_step, observation_interval)

# %%
radius = 10
localization_matrix = jnp.ones((n, n))#generate_gc_localization_matrix(n, radius)
ensemble_init = random.multivariate_normal(key, initial_state, Q, (n_ensemble,)).T
inflation = 1
e, c = ensrf_steps(A_step, n_ensemble, ensemble_init, num_steps, observations, observation_interval, H, Q, R, localization_matrix, inflation, key)

# %%
# plt.pcolormesh(c[-1])
# plt.colorbar()

# %%
from jax_vi import KL_gaussian, log_likelihood, KL_sum

def var_cost(inflation, ensemble_init, observations, H, Q, R, localization_matrix, key, num_steps, J0):
   
    states, covariances = ensrf_steps(A_step, n_ensemble, ensemble_init, num_steps, observations, observation_interval, H, Q, R, localization_matrix, inflation, key)
    ensemble_mean = jnp.mean(states, axis=-1)  # Taking the mean across the ensemble members dimension
    key, *subkeys = random.split(key, num=N+1)
    kl_sum = KL_sum(ensemble_mean, covariances, n, A_step, Q, key, N)

    def inner_map(subkey):
        return log_likelihood(random.multivariate_normal(subkey, ensemble_mean, covariances), observations, H, R, num_steps, J0)  # Sometimes the covariances are negative definite. Fix
    cost = kl_sum - jnp.nanmean(jax.lax.map(inner_map, jnp.vstack(subkeys)))
    
    return cost

# %%
var_cost(1, ensemble_init, observations, H, Q, R, localization_matrix, key, num_steps, J0)
# Out:
# Array(12702.295, dtype=float32)

# %%
jnp.arange(1.0, 1.5, 0.02)
# Out:
# Array([1.       , 1.02     , 1.04     , 1.06     , 1.0799999, 1.0999999,
#        1.1199999, 1.1399999, 1.1599998, 1.1799998, 1.1999998, 1.2199998,
#        1.2399998, 1.2599998, 1.2799997, 1.2999997, 1.3199997, 1.3399997,
#        1.3599997, 1.3799996, 1.3999996, 1.4199996, 1.4399996, 1.4599996,
#        1.4799995], dtype=float32)

# %%
hum = []
for inflation in jnp.arange(1.0, 25, 1):
    hum.append(var_cost_grad(inflation, ensemble_init, observations, H, Q, R, localization_matrix, key, num_steps, J0))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 3
#       1 hum = []
#       2 for inflation in jnp.arange(1.0, 25, 1):
# ----> 3     hum.append(var_cost_grad(inflation, ensemble_init, observations, H, Q, R, localization_matrix, key, num_steps, J0))
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/api.py:659, in grad.<locals>.grad_f(*args, **kwargs)
#     656 @wraps(fun, docstr=docstr, argnums=argnums)
#     657 @api_boundary
#     658 def grad_f(*args, **kwargs):
# --> 659   _, g = value_and_grad_f(*args, **kwargs)
#     660   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/api.py:735, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     733   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     734 if not has_aux:
# --> 735   ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     736 else:
#     737   ans, vjp_py, aux = _vjp(
#     738       f_partial, *dyn_args, has_aux=True, reduce_axes=reduce_axes)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/api.py:2223, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2221 if not has_aux:
#    2222   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2223   out_primal, out_vjp = ad.vjp(
#    2224       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2225   out_tree = out_tree()
#    2226 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:142, in vjp(traceable, primals, has_aux, reduce_axes)
#     140 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# Cell In[51], line 12, in var_cost(inflation, ensemble_init, observations, H, Q, R, localization_matrix, key, num_steps, J0)
#      10 def inner_map(subkey):
#      11     return log_likelihood(random.multivariate_normal(subkey, ensemble_mean, covariances), observations, H, R, num_steps, J0)  # Sometimes the covariances are negative definite. Fix
# ---> 12 cost = kl_sum - jnp.nanmean(jax.lax.map(inner_map, jnp.vstack(subkeys)))
#      14 return cost
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:2010, in map(f, xs)
#    1983 """Map a function over leading array axes.
#    1984
#    1985 Like Python's builtin map, except inputs and outputs are in the form of
#    (...)
#    2007   Mapped values.
#    2008 """
#    2009 g = lambda _, x: ((), f(x))
# -> 2010 _, ys = scan(g, (), xs)
#    2011 return ys
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:273, in scan(f, init, xs, length, reverse, unroll)
#     271 if isinstance(unroll, bool):
#     272   unroll = length if unroll else 1
# --> 273 out = scan_p.bind(*consts, *in_flat,
#     274                   reverse=reverse, length=length, jaxpr=jaxpr,
#     275                   num_consts=len(consts), num_carry=len(init_flat),
#     276                   linear=(False,) * (len(consts) + len(in_flat)),
#     277                   unroll=unroll)
#     278 return tree_unflatten(out_tree, out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1130, in scan_bind(*args, **params)
#    1128   _scan_typecheck(True, *in_atoms, **params)
#    1129   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1130 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:318, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     316   msg = f"Differentiation rule for '{primitive}' not implemented"
#     317   raise NotImplementedError(msg)
# --> 318 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     319 if primitive.multiple_results:
#     320   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:555, in _scan_jvp(primals, tangents, reverse, length, jaxpr, num_consts, num_carry, linear, unroll)
#     550 consts_linear, init_linear, xs_linear = split_list(linear, [num_consts, num_carry])
#     551 jaxpr_jvp_linear = tuple(consts_linear + [True] * len(consts_dot)
#     552                          + init_linear + [True] * len(init_dot)
#     553                          + xs_linear + [True] * len(xs_dot))
# --> 555 out_flat = scan_p.bind(
#     556     *(consts + consts_dot + init + init_dot + xs + xs_dot),
#     557     reverse=reverse, length=length, jaxpr=jaxpr_jvp_rearranged,
#     558     num_consts=num_consts + len(consts_dot),
#     559     num_carry=num_carry + len(init_dot),
#     560     linear=jaxpr_jvp_linear, unroll=unroll)
#     562 carry, carry_dot, ys, ys_dot = split_list(out_flat, [num_carry, len(init_dot), num_ys])
#     563 primals_out = carry + ys
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1130, in scan_bind(*args, **params)
#    1128   _scan_typecheck(True, *in_atoms, **params)
#    1129   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1130 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:212, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     210 def process_primitive(self, primitive, tracers, params):
#     211   if primitive in custom_partial_eval_rules:
# --> 212     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     213   else:
#     214     return self.default_process_primitive(primitive, tracers, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:665, in _scan_partial_eval(trace, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, *tracers)
#     663 else:
#     664   linear_known = [False] * len(known_inputs)  # conservative!
# --> 665   out_known = scan_p.bind(
#     666       *known_inputs, reverse=reverse, length=length, jaxpr=jaxpr_known,
#     667       num_consts=len(jaxpr_known_consts), num_carry=num_carry - sum(carry_uk),
#     668       linear=tuple(linear_known), unroll=unroll)
#     669   del linear_known
#     670 # Complete the known output by filling in forwarded values using fwds_known.
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1130, in scan_bind(*args, **params)
#    1128   _scan_typecheck(True, *in_atoms, **params)
#    1129   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1130 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:935, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     934 def process_primitive(self, primitive, tracers, params):
# --> 935   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:257, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255 @api_boundary
#     256 def cache_miss(*args, **kwargs):
# --> 257   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     258       fun, infer_params_fn, *args, **kwargs)
#     259   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     260   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:168, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     166   dispatch.check_arg(arg)
#     167 try:
# --> 168   out_flat = pjit_p.bind(*args_flat, **params)
#     169 except pxla.DeviceAssignmentMismatchError as e:
#     170   fails, = e.args
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:935, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     934 def process_primitive(self, primitive, tracers, params):
# --> 935   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:1245, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1242 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1243 has_explicit_sharding = _pjit_explicit_sharding(
#    1244     in_shardings, out_shardings, None, None)
# -> 1245 return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1246                     tree_util.dispatch_registry,
#    1247                     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:1229, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1228 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1229   out_flat, compiled = _pjit_call_impl_python(
#    1230       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1231       out_shardings=out_shardings, resource_env=resource_env,
#    1232       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1233       inline=inline)
#    1234   fastpath_data = _get_fastpath_data(
#    1235       compiled, tree_structure(out_flat), args, out_flat)
#    1236   return out_flat, fastpath_data
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:1162, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1156 global _most_recent_pjit_call_executable
#    1158 in_shardings = _resolve_in_shardings(
#    1159     args, in_shardings, out_shardings,
#    1160     resource_env.physical_mesh if resource_env is not None else None)
# -> 1162 compiled = _pjit_lower(
#    1163     jaxpr, in_shardings, out_shardings, resource_env,
#    1164     donated_invars, name, keep_unused, inline,
#    1165     lowering_parameters=mlir.LoweringParameters()).compile()
#    1166 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1167 # This check is expensive so only do it if enable_checks is on.
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2219, in MeshComputation.compile(self, compiler_options)
#    2217 def compile(self, compiler_options=None) -> MeshExecutable:
#    2218   if self._executable is None or compiler_options is not None:
# -> 2219     executable = UnloadedMeshExecutable.from_hlo(
#    2220         self._name, self._hlo, **self.compile_args,
#    2221         compiler_options=compiler_options)
#    2222     if compiler_options is None:
#    2223       self._executable = executable
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2659, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2656       mesh = i.mesh  # type: ignore
#    2657       break
# -> 2659 xla_executable, compile_options = _cached_compilation(
#    2660     hlo, name, mesh, spmd_lowering,
#    2661     tuple_args, auto_spmd_lowering, allow_prop_to_outputs,
#    2662     tuple(host_callbacks), backend, da, pmap_nreps,
#    2663     compiler_options_keys, compiler_options_values)
#    2665 if hasattr(backend, "compile_replicated"):
#    2666   semantics_in_shardings = SemanticallyEqualShardings(in_shardings)  # type: ignore
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2528, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, _allow_propagation_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values)
#    2523   return None, compile_options
#    2525 with dispatch.log_elapsed_time(
#    2526     "Finished XLA compilation of {fun_name} in {elapsed_time} sec",
#    2527     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2528   xla_executable = compiler.compile_or_get_cached(
#    2529       backend, computation, dev, compile_options, host_callbacks)
#    2530 return xla_executable, compile_options
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/compiler.py:296, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks)
#     292 use_compilation_cache = (compilation_cache.is_initialized() and
#     293                          backend.platform in supported_platforms)
#     295 if not use_compilation_cache:
# --> 296   return backend_compile(backend, computation, compile_options,
#     297                          host_callbacks)
#     299 compilation_cache.set_once_cache_used(
#     300     lambda: monitoring.record_event(
#     301         "/jax/compilation_cache/tasks_using_cache"))
#     302 monitoring.record_event('/jax/compilation_cache/compile_requests_use_cache')
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/compiler.py:256, in backend_compile(backend, module, options, host_callbacks)
#     251   return backend.compile(built_c, compile_options=options,
#     252                          host_callbacks=host_callbacks)
#     253 # Some backends don't have `host_callbacks` option yet
#     254 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     255 # to take in `host_callbacks`
# --> 256 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
hum
# Out:
# []

# %%
m, C, K = kalman_filter_process(A_step, jac_func, m0, C0, observations, H, Q, R)

# %%
from IPython.display import clear_output
from jax import grad
from tqdm.notebook import tqdm
import jax.numpy as jnp
from jax import random
import properscoring


# Modification: Use grad to compute the gradient with respect to the inflation parameter
var_cost_grad = grad(var_cost, argnums=0)

radius = 4
inflation_opt = 1.2 # Example starting value for inflation
alpha = 1e-6  # Learning rate
key = random.PRNGKey(0)  # Random key
N = 10  # Number of MC samples
m0 = initial_state
C0 = Q  # Initial covariance, assuming Q is your process noise covariance
localization_matrix = generate_gc_localization_matrix(n, radius)# jnp.ones((n, n)) # 
ensemble_init = random.multivariate_normal(key, initial_state, Q, (n_ensemble,)).T

crpss = []
rmses=[]
inflations = []
true_div = []
# from jax import config
# config.update("jax_debug_nans", True)

for i in tqdm(range(10)):
    key, subkey = random.split(key)
        
    # Gradient descent step for inflation parameter
    grad_inflation = var_cost_grad(inflation_opt, ensemble_init, observations, H, Q, R, localization_matrix, subkey, num_steps, J0)
    inflation_opt -= alpha * grad_inflation  # Update inflation parameter
    
    inflations.append(inflation_opt)

    states, covariances = ensrf_steps(A_step, n_ensemble, ensemble_init, num_steps, observations, observation_interval, H, Q, R, localization_matrix, inflation_opt, key)
    ensemble_mean = jnp.mean(states, axis=-1)  # Taking the mean across the ensemble members dimension
    rmse = jnp.sqrt(jnp.mean((ensemble_mean - true_states)**2))
    rmses.append(rmse)
    crps = properscoring.crps_ensemble(true_states, states).mean(axis=1).mean()
    crpss.append(crps)
    total_kl_divergence = 0
    for t in range(num_steps):  
        kl_div_t = KL_gaussian(n, ensemble_mean[t], covariances[t],  m[t], C[t])
        total_kl_divergence += kl_div_t/num_steps
    
    true_div.append(total_kl_divergence)
    #clear_output(wait=True)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 33
#      30 key, subkey = random.split(key)
#      32 # Gradient descent step for inflation parameter
# ---> 33 grad_inflation = var_cost_grad(inflation_opt, ensemble_init, observations, H, Q, R, localization_matrix, subkey, num_steps, J0)
#      34 inflation_opt -= alpha * grad_inflation  # Update inflation parameter
#      36 inflations.append(inflation_opt)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/api.py:659, in grad.<locals>.grad_f(*args, **kwargs)
#     656 @wraps(fun, docstr=docstr, argnums=argnums)
#     657 @api_boundary
#     658 def grad_f(*args, **kwargs):
# --> 659   _, g = value_and_grad_f(*args, **kwargs)
#     660   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/api.py:735, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     733   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     734 if not has_aux:
# --> 735   ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     736 else:
#     737   ans, vjp_py, aux = _vjp(
#     738       f_partial, *dyn_args, has_aux=True, reduce_axes=reduce_axes)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/api.py:2223, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2221 if not has_aux:
#    2222   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2223   out_primal, out_vjp = ad.vjp(
#    2224       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2225   out_tree = out_tree()
#    2226 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:142, in vjp(traceable, primals, has_aux, reduce_axes)
#     140 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     141   if not has_aux:
# --> 142     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     143   else:
#     144     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:131, in linearize(traceable, *primals, **kwargs)
#     129 _, in_tree = tree_flatten(((primals, primals), {}))
#     130 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 131 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     132 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     133 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/linear_util.py:191, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     188 gen = gen_static_args = out_store = None
#     190 try:
# --> 191   ans = self.f(*args, **dict(self.params, **kwargs))
#     192 except:
#     193   # Some transformations yield from inside context managers, so we have to
#     194   # interrupt them before reraising the exception. Otherwise they will only
#     195   # get garbage-collected at some later time, running their cleanup tasks
#     196   # only after this exception is handled, which can corrupt the global
#     197   # state.
#     198   while stack:
#
# Cell In[51], line 12, in var_cost(inflation, ensemble_init, observations, H, Q, R, localization_matrix, key, num_steps, J0)
#      10 def inner_map(subkey):
#      11     return log_likelihood(random.multivariate_normal(subkey, ensemble_mean, covariances), observations, H, R, num_steps, J0)  # Sometimes the covariances are negative definite. Fix
# ---> 12 cost = kl_sum - jnp.nanmean(jax.lax.map(inner_map, jnp.vstack(subkeys)))
#      14 return cost
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:2010, in map(f, xs)
#    1983 """Map a function over leading array axes.
#    1984
#    1985 Like Python's builtin map, except inputs and outputs are in the form of
#    (...)
#    2007   Mapped values.
#    2008 """
#    2009 g = lambda _, x: ((), f(x))
# -> 2010 _, ys = scan(g, (), xs)
#    2011 return ys
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:273, in scan(f, init, xs, length, reverse, unroll)
#     271 if isinstance(unroll, bool):
#     272   unroll = length if unroll else 1
# --> 273 out = scan_p.bind(*consts, *in_flat,
#     274                   reverse=reverse, length=length, jaxpr=jaxpr,
#     275                   num_consts=len(consts), num_carry=len(init_flat),
#     276                   linear=(False,) * (len(consts) + len(in_flat)),
#     277                   unroll=unroll)
#     278 return tree_unflatten(out_tree, out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1130, in scan_bind(*args, **params)
#    1128   _scan_typecheck(True, *in_atoms, **params)
#    1129   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1130 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/ad.py:318, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     316   msg = f"Differentiation rule for '{primitive}' not implemented"
#     317   raise NotImplementedError(msg)
# --> 318 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     319 if primitive.multiple_results:
#     320   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:555, in _scan_jvp(primals, tangents, reverse, length, jaxpr, num_consts, num_carry, linear, unroll)
#     550 consts_linear, init_linear, xs_linear = split_list(linear, [num_consts, num_carry])
#     551 jaxpr_jvp_linear = tuple(consts_linear + [True] * len(consts_dot)
#     552                          + init_linear + [True] * len(init_dot)
#     553                          + xs_linear + [True] * len(xs_dot))
# --> 555 out_flat = scan_p.bind(
#     556     *(consts + consts_dot + init + init_dot + xs + xs_dot),
#     557     reverse=reverse, length=length, jaxpr=jaxpr_jvp_rearranged,
#     558     num_consts=num_consts + len(consts_dot),
#     559     num_carry=num_carry + len(init_dot),
#     560     linear=jaxpr_jvp_linear, unroll=unroll)
#     562 carry, carry_dot, ys, ys_dot = split_list(out_flat, [num_carry, len(init_dot), num_ys])
#     563 primals_out = carry + ys
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1130, in scan_bind(*args, **params)
#    1128   _scan_typecheck(True, *in_atoms, **params)
#    1129   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1130 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/partial_eval.py:212, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     210 def process_primitive(self, primitive, tracers, params):
#     211   if primitive in custom_partial_eval_rules:
# --> 212     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     213   else:
#     214     return self.default_process_primitive(primitive, tracers, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:665, in _scan_partial_eval(trace, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, *tracers)
#     663 else:
#     664   linear_known = [False] * len(known_inputs)  # conservative!
# --> 665   out_known = scan_p.bind(
#     666       *known_inputs, reverse=reverse, length=length, jaxpr=jaxpr_known,
#     667       num_consts=len(jaxpr_known_consts), num_carry=num_carry - sum(carry_uk),
#     668       linear=tuple(linear_known), unroll=unroll)
#     669   del linear_known
#     670 # Complete the known output by filling in forwarded values using fwds_known.
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1130, in scan_bind(*args, **params)
#    1128   _scan_typecheck(True, *in_atoms, **params)
#    1129   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1130 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:935, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     934 def process_primitive(self, primitive, tracers, params):
# --> 935   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:257, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255 @api_boundary
#     256 def cache_miss(*args, **kwargs):
# --> 257   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     258       fun, infer_params_fn, *args, **kwargs)
#     259   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     260   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:168, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     166   dispatch.check_arg(arg)
#     167 try:
# --> 168   out_flat = pjit_p.bind(*args_flat, **params)
#     169 except pxla.DeviceAssignmentMismatchError as e:
#     170   fails, = e.args
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/core.py:935, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     934 def process_primitive(self, primitive, tracers, params):
# --> 935   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:1245, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1242 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1243 has_explicit_sharding = _pjit_explicit_sharding(
#    1244     in_shardings, out_shardings, None, None)
# -> 1245 return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1246                     tree_util.dispatch_registry,
#    1247                     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:1229, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1228 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1229   out_flat, compiled = _pjit_call_impl_python(
#    1230       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1231       out_shardings=out_shardings, resource_env=resource_env,
#    1232       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1233       inline=inline)
#    1234   fastpath_data = _get_fastpath_data(
#    1235       compiled, tree_structure(out_flat), args, out_flat)
#    1236   return out_flat, fastpath_data
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:1162, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1156 global _most_recent_pjit_call_executable
#    1158 in_shardings = _resolve_in_shardings(
#    1159     args, in_shardings, out_shardings,
#    1160     resource_env.physical_mesh if resource_env is not None else None)
# -> 1162 compiled = _pjit_lower(
#    1163     jaxpr, in_shardings, out_shardings, resource_env,
#    1164     donated_invars, name, keep_unused, inline,
#    1165     lowering_parameters=mlir.LoweringParameters()).compile()
#    1166 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1167 # This check is expensive so only do it if enable_checks is on.
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2219, in MeshComputation.compile(self, compiler_options)
#    2217 def compile(self, compiler_options=None) -> MeshExecutable:
#    2218   if self._executable is None or compiler_options is not None:
# -> 2219     executable = UnloadedMeshExecutable.from_hlo(
#    2220         self._name, self._hlo, **self.compile_args,
#    2221         compiler_options=compiler_options)
#    2222     if compiler_options is None:
#    2223       self._executable = executable
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2659, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2656       mesh = i.mesh  # type: ignore
#    2657       break
# -> 2659 xla_executable, compile_options = _cached_compilation(
#    2660     hlo, name, mesh, spmd_lowering,
#    2661     tuple_args, auto_spmd_lowering, allow_prop_to_outputs,
#    2662     tuple(host_callbacks), backend, da, pmap_nreps,
#    2663     compiler_options_keys, compiler_options_values)
#    2665 if hasattr(backend, "compile_replicated"):
#    2666   semantics_in_shardings = SemanticallyEqualShardings(in_shardings)  # type: ignore
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2528, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, _allow_propagation_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values)
#    2523   return None, compile_options
#    2525 with dispatch.log_elapsed_time(
#    2526     "Finished XLA compilation of {fun_name} in {elapsed_time} sec",
#    2527     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2528   xla_executable = compiler.compile_or_get_cached(
#    2529       backend, computation, dev, compile_options, host_callbacks)
#    2530 return xla_executable, compile_options
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/compiler.py:296, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks)
#     292 use_compilation_cache = (compilation_cache.is_initialized() and
#     293                          backend.platform in supported_platforms)
#     295 if not use_compilation_cache:
# --> 296   return backend_compile(backend, computation, compile_options,
#     297                          host_callbacks)
#     299 compilation_cache.set_once_cache_used(
#     300     lambda: monitoring.record_event(
#     301         "/jax/compilation_cache/tasks_using_cache"))
#     302 monitoring.record_event('/jax/compilation_cache/compile_requests_use_cache')
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/compiler.py:256, in backend_compile(backend, module, options, host_callbacks)
#     251   return backend.compile(built_c, compile_options=options,
#     252                          host_callbacks=host_callbacks)
#     253 # Some backends don't have `host_callbacks` option yet
#     254 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     255 # to take in `host_callbacks`
# --> 256 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
from jax import config
config.update("jax_debug_nans", True)

var_cost_grad(1.1, ensemble_init, observations, H, Q, R, localization_matrix, subkey, num_steps, J0)
# Out:
# Invalid nan value encountered in the output of a C++-jit/pmap function. Calling the de-optimized version.
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:322, in check_special(name, bufs)
#     321 for buf in bufs:
# --> 322   _check_special(name, buf.dtype, buf)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:327, in _check_special(name, dtype, buf)
#     326 if config.debug_nans.value and np.any(np.isnan(np.asarray(buf))):
# --> 327   raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     328 if config.debug_infs.value and np.any(np.isinf(np.asarray(buf))):
#
# FloatingPointError: invalid value (nan) encountered in pjit
#
# During handling of the above exception, another exception occurred:
#
# FloatingPointError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     335 with TraceAnnotation(name, **decorator_kwargs):
# --> 336   return func(*args, **kwargs)
#     337 return wrapper
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1163, in ExecuteReplicated.__call__(self, *args)
#    1162 for arrays in out_arrays:
# -> 1163   dispatch.check_special(self.name, arrays)
#    1164 return self.out_handler(out_arrays)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:322, in check_special(name, bufs)
#     321 for buf in bufs:
# --> 322   _check_special(name, buf.dtype, buf)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:327, in _check_special(name, dtype, buf)
#     326 if config.debug_nans.value and np.any(np.isnan(np.asarray(buf))):
# --> 327   raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     328 if config.debug_infs.value and np.any(np.isinf(np.asarray(buf))):
#
# FloatingPointError: invalid value (nan) encountered in jit(ensrf_steps)
#
# During handling of the above exception, another exception occurred:
#
# FloatingPointError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     335 with TraceAnnotation(name, **decorator_kwargs):
# --> 336   return func(*args, **kwargs)
#     337 return wrapper
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1163, in ExecuteReplicated.__call__(self, *args)
#    1162 for arrays in out_arrays:
# -> 1163   dispatch.check_special(self.name, arrays)
#    1164 return self.out_handler(out_arrays)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:322, in check_special(name, bufs)
#     321 for buf in bufs:
# --> 322   _check_special(name, buf.dtype, buf)
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/dispatch.py:327, in _check_special(name, dtype, buf)
#     326 if config.debug_nans.value and np.any(np.isnan(np.asarray(buf))):
# --> 327   raise FloatingPointError(f"invalid value (nan) encountered in {name}")
#     328 if config.debug_infs.value and np.any(np.isinf(np.asarray(buf))):
#
# FloatingPointError: invalid value (nan) encountered in jit(scan)
#
# During handling of the above exception, another exception occurred:
#
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/runpy.py:197, in _run_module_as_main()
#     196     sys.argv[0] = mod_spec.origin
# --> 197 return _run_code(code, main_globals, None,
#     198                  "__main__", mod_spec)
#
# File ~/miniconda3/lib/python3.9/runpy.py:87, in _run_code()
#      80 run_globals.update(__name__ = mod_name,
#      81                    __file__ = fname,
#      82                    __cached__ = cached,
#    (...)
#      85                    __package__ = pkg_name,
#      86                    __spec__ = mod_spec)
# ---> 87 exec(code, run_globals)
#      88 return run_globals
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel_launcher.py:17
#      15 from ipykernel import kernelapp as app
# ---> 17 app.launch_new_instance()
#
# File ~/miniconda3/lib/python3.9/site-packages/traitlets/config/application.py:1043, in launch_instance()
#    1042 app.initialize(argv)
# -> 1043 app.start()
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py:725, in start()
#     724 try:
# --> 725     self.io_loop.start()
#     726 except KeyboardInterrupt:
#
# File ~/miniconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py:195, in start()
#     194 def start(self) -> None:
# --> 195     self.asyncio_loop.run_forever()
#
# File ~/miniconda3/lib/python3.9/asyncio/base_events.py:601, in run_forever()
#     600 while True:
# --> 601     self._run_once()
#     602     if self._stopping:
#
# File ~/miniconda3/lib/python3.9/asyncio/base_events.py:1905, in _run_once()
#    1904     else:
# -> 1905         handle._run()
#    1906 handle = None
#
# File ~/miniconda3/lib/python3.9/asyncio/events.py:80, in _run()
#      79 try:
# ---> 80     self._context.run(self._callback, *self._args)
#      81 except (SystemExit, KeyboardInterrupt):
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:513, in dispatch_queue()
#     512 try:
# --> 513     await self.process_one()
#     514 except Exception:
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:502, in process_one()
#     501         return None
# --> 502 await dispatch(*args)
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:409, in dispatch_shell()
#     408     if inspect.isawaitable(result):
# --> 409         await result
#     410 except Exception:
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:729, in execute_request()
#     728 if inspect.isawaitable(reply_content):
# --> 729     reply_content = await reply_content
#     731 # Flush output before sending the reply.
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py:422, in do_execute()
#     421 if with_cell_id:
# --> 422     res = shell.run_cell(
#     423         code,
#     424         store_history=store_history,
#     425         silent=silent,
#     426         cell_id=cell_id,
#     427     )
#     428 else:
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py:540, in run_cell()
#     539 self._last_traceback = None
# --> 540 return super().run_cell(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3009, in run_cell()
#    3008 try:
# -> 3009     result = self._run_cell(
#    3010         raw_cell, store_history, silent, shell_futures, cell_id
#    3011     )
#    3012 finally:
#
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3064, in _run_cell()
#    3063 try:
# -> 3064     result = runner(coro)
#    3065 except BaseException as e:
#
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner()
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3269, in run_cell_async()
#    3266 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3269 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3270        interactivity=interactivity, compiler=compiler, result=result)
#    3272 self.last_execution_succeeded = not has_raised
#
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3448, in run_ast_nodes()
#    3447     asy = compare(code)
# -> 3448 if await self.run_code(code, result, async_=asy):
#    3449     return True
#
# File ~/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3508, in run_code()
#    3507     else:
# -> 3508         exec(code_obj, self.user_global_ns, self.user_ns)
#    3509 finally:
#    3510     # Reset our crash handler in place
#
# Cell In[78], line 1
# ----> 1 var_cost_grad(1.4, ensemble_init, observations, H, Q, R, localization_matrix, subkey, num_steps, J0)
#
# Cell In[114], line 5, in var_cost()
#       3 def var_cost(inflation, ensemble_init, observations, H, Q, R, localization_matrix, key, num_steps, J0):
# ----> 5     states, covariances = ensrf_steps(A_step, n_ensemble, ensemble_init, num_steps, observations, observation_interval, H, Q, R, localization_matrix, inflation, key)
#       6     ensemble_mean = jnp.mean(states, axis=-1)  # Taking the mean across the ensemble members dimension
#
# File /central/groups/esm/ebach/variational_filtering/jax_filters.py:114, in ensrf_steps()
#     113 covariance_init = jnp.zeros((n,n))
# --> 114 _, output = jax.lax.scan(inner, (ensemble_init, covariance_init), jnp.arange(num_steps))
#     115 ensembles, covariances = output
#
# JaxStackTraceBeforeTransformation: FloatingPointError: invalid value (nan) encountered in jit(scan). Because jax_config.debug_nans.value and/or config.jax_debug_infs is set, the de-optimized function (i.e., the function as if the `jit` decorator were removed) was called in an attempt to get a more precise error message. However, the de-optimized function did not produce invalid values during its execution. This behavior can result from `jit` optimizations causing the invalid value to be produced. It may also arise from having nan/inf constants as outputs, like `jax.jit(lambda ...: jax.numpy.nan)(...)`.
#
# It may be possible to avoid the invalid value by removing the `jit` decorator, at the cost of losing optimizations.
#
# If you see this error, consider opening a bug report at https://github.com/google/jax.
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# FloatingPointError                        Traceback (most recent call last)
# Cell In[120], line 4
#       1 from jax import config
#       2 config.update("jax_debug_nans", True)
# ----> 4 var_cost_grad(1.1, ensemble_init, observations, H, Q, R, localization_matrix, subkey, num_steps, J0)
#
#     [... skipping hidden 32 frame]
#
# File ~/miniconda3/lib/python3.9/site-packages/jax/_src/pjit.py:1209, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1192 # If control reaches this line, we got a NaN on the output of `compiled`
#    1193 # but not `fun.call_wrapped` on the same arguments. Let's tell the user.
#    1194 msg = (f"{str(e)}. Because "
#    1195        "jax_config.debug_nans.value and/or config.jax_debug_infs is set, the "
#    1196        "de-optimized function (i.e., the function as if the `jit` "
#    (...)
#    1207        "If you see this error, consider opening a bug report at "
#    1208        "https://github.com/google/jax.")
# -> 1209 raise FloatingPointError(msg)
#
# FloatingPointError: invalid value (nan) encountered in jit(scan). Because jax_config.debug_nans.value and/or config.jax_debug_infs is set, the de-optimized function (i.e., the function as if the `jit` decorator were removed) was called in an attempt to get a more precise error message. However, the de-optimized function did not produce invalid values during its execution. This behavior can result from `jit` optimizations causing the invalid value to be produced. It may also arise from having nan/inf constants as outputs, like `jax.jit(lambda ...: jax.numpy.nan)(...)`.
#
# It may be possible to avoid the invalid value by removing the `jit` decorator, at the cost of losing optimizations.
#
# If you see this error, consider opening a bug report at https://github.com/google/jax.

# %%
ins = []
cs = []
ds = []

for i in jnp.arange(1.0, 4.0, 0.05):
    states, covariances = ensrf_steps(A_step, n_ensemble, ensemble_init, num_steps, observations, observation_interval, H, Q, R, localization_matrix, i, key)
    ensemble_mean = jnp.mean(states, axis=-1)  # Taking the mean across the ensemble members dimension
    total_kl_divergence = 0
    for t in range(num_steps):  
        kl_div_t = KL_gaussian(n, ensemble_mean[t], covariances[t],  m[t], C[t])
        total_kl_divergence += kl_div_t/num_steps

    c = var_cost(i, ensemble_init, observations, H, Q, R, localization_matrix, subkey, num_steps, J0)
    print(i, c, total_kl_divergence)
    cs.append(c)
    ds.append(total_kl_divergence)
    ins.append(i)
# Out:
# 1.0 12700.823 119.44068
# 1.05 11231.766 104.74386
# 1.0999999 9238.619 84.80562
# 1.1499999 7125.301 63.66431
# 1.1999998 5201.0225 44.409
# 1.2499998 3693.5513 29.295858
# 1.2999997 2980.5776 22.048157
# 1.3499997 2597.018 18.044703
# 1.3999996 2368.4468 15.551994
# 1.4499996 2238.6433 14.05187
# 1.4999995 2156.3013 13.038725
# 1.5499995 2100.1846 12.299426
# 1.5999994 2059.9102 11.728783
# 1.6499994 2029.2147 11.262911
# 1.6999993 2002.5663 10.845228
# 1.7499993 1968.0404 10.353281
# 1.7999992 1913.4594 9.657496
# 1.8499992 1873.585 9.106427
# 1.8999991 1849.5742 8.717615
# 1.9499991 1834.6931 8.425714
# 1.999999 1825.5768 8.197516
# 2.049999 1820.3585 8.014301
# 2.099999 1817.8627 7.864108
# 2.149999 1817.2777 7.7385573
# 2.1999989 1817.9966 7.631258
# 2.2499988 1819.5125 7.5368
# 2.2999988 1821.3193 7.449662
# 2.3499987 1822.7183 7.362208
# 2.3999987 1822.1642 7.257827
# 2.4499986 1815.1156 7.0888615
# 2.4999986 1799.2996 6.8308535
# 2.5499985 1786.341 6.6019306
# 2.5999985 1779.3298 6.4348464
# 2.6499984 1776.235 6.3100495
# 2.6999984 1775.5339 6.2125263
# 2.7499983 1776.2578 6.1326003
# 2.7999983 1777.6748 6.062867
# 2.8499982 1779.021 5.995493
# 2.8999982 1779.0183 5.9171567
# 2.9499981 1774.9747 5.799496
# 2.999998 1765.7415 5.62928
# 3.049998 1756.9099 5.462958
# 3.099998 1750.9285 5.326219
# 3.149998 1746.0162 5.2012396
# 3.199998 1739.2129 5.0572867
# 3.2499979 1730.6572 4.894996
# 3.2999978 1724.576 4.758078
# 3.3499978 1722.1526 4.6599016
# 3.3999977 1722.6111 4.593149
# 3.4499977 1725.1508 4.549791
# 3.4999976 1729.2035 4.524024
# 3.5499976 1734.3737 4.5117607
# 3.5999975 1740.3805 4.5100546
# 3.6499975 1747.0166 4.5167184
# 3.6999974 1754.1257 4.530081
# 3.7499974 1761.5872 4.548847
# 3.7999973 1769.3074 4.5719805
# 3.8499973 1777.2107 4.5986514
# 3.8999972 1785.237 4.628183
# 3.9499972 1793.3373 4.6600094

# %%
plt.plot([ins, cs, ds])
# Out:
# [<matplotlib.lines.Line2D at 0x7faab7c4d550>,
#  <matplotlib.lines.Line2D at 0x7faab7c4da00>,
#  <matplotlib.lines.Line2D at 0x7faab7c4d3a0>,
#  <matplotlib.lines.Line2D at 0x7faab7c4db80>,
#  <matplotlib.lines.Line2D at 0x7faab778c310>,
#  <matplotlib.lines.Line2D at 0x7faab778cc70>,
#  <matplotlib.lines.Line2D at 0x7faab778c7f0>,
#  <matplotlib.lines.Line2D at 0x7faab778c5b0>,
#  <matplotlib.lines.Line2D at 0x7faab778c8b0>,
#  <matplotlib.lines.Line2D at 0x7faab778c880>,
#  <matplotlib.lines.Line2D at 0x7faab7c4d100>,
#  <matplotlib.lines.Line2D at 0x7faab7c50b80>,
#  <matplotlib.lines.Line2D at 0x7faab7c50f10>,
#  <matplotlib.lines.Line2D at 0x7faab7c50d90>,
#  <matplotlib.lines.Line2D at 0x7faab7c50310>,
#  <matplotlib.lines.Line2D at 0x7faab755d5e0>,
#  <matplotlib.lines.Line2D at 0x7faab755d790>,
#  <matplotlib.lines.Line2D at 0x7faab755da00>,
#  <matplotlib.lines.Line2D at 0x7faab755d970>,
#  <matplotlib.lines.Line2D at 0x7faab755d8b0>,
#  <matplotlib.lines.Line2D at 0x7faab755d4c0>,
#  <matplotlib.lines.Line2D at 0x7faab755d130>,
#  <matplotlib.lines.Line2D at 0x7faab755dd00>,
#  <matplotlib.lines.Line2D at 0x7faab755daf0>,
#  <matplotlib.lines.Line2D at 0x7faab755dc40>,
#  <matplotlib.lines.Line2D at 0x7faab755dc10>,
#  <matplotlib.lines.Line2D at 0x7faab755deb0>,
#  <matplotlib.lines.Line2D at 0x7faab755d730>,
#  <matplotlib.lines.Line2D at 0x7faab755d7f0>,
#  <matplotlib.lines.Line2D at 0x7faab784cf40>,
#  <matplotlib.lines.Line2D at 0x7faab784c2e0>,
#  <matplotlib.lines.Line2D at 0x7faab7799df0>,
#  <matplotlib.lines.Line2D at 0x7faab7799f70>,
#  <matplotlib.lines.Line2D at 0x7faab7799640>,
#  <matplotlib.lines.Line2D at 0x7faab7e5ec10>,
#  <matplotlib.lines.Line2D at 0x7faab7e5ed60>,
#  <matplotlib.lines.Line2D at 0x7faab7e5e3a0>,
#  <matplotlib.lines.Line2D at 0x7faab7e5efd0>,
#  <matplotlib.lines.Line2D at 0x7faab7e5e370>,
#  <matplotlib.lines.Line2D at 0x7faab7e5e8e0>,
#  <matplotlib.lines.Line2D at 0x7faab7e5e970>,
#  <matplotlib.lines.Line2D at 0x7faab7e5eeb0>,
#  <matplotlib.lines.Line2D at 0x7faab7e5eac0>,
#  <matplotlib.lines.Line2D at 0x7faab7e5edf0>,
#  <matplotlib.lines.Line2D at 0x7faab7e5ef70>,
#  <matplotlib.lines.Line2D at 0x7faab7b9f160>,
#  <matplotlib.lines.Line2D at 0x7faab7b9f4f0>,
#  <matplotlib.lines.Line2D at 0x7faab7c65a60>,
#  <matplotlib.lines.Line2D at 0x7faab7c651f0>,
#  <matplotlib.lines.Line2D at 0x7faab7c65e50>,
#  <matplotlib.lines.Line2D at 0x7faab7c65370>,
#  <matplotlib.lines.Line2D at 0x7faab7c65190>,
#  <matplotlib.lines.Line2D at 0x7faab7c657c0>,
#  <matplotlib.lines.Line2D at 0x7faab7c65ac0>,
#  <matplotlib.lines.Line2D at 0x7faab7a3be20>,
#  <matplotlib.lines.Line2D at 0x7faab7a3bfd0>,
#  <matplotlib.lines.Line2D at 0x7faab7a3b940>,
#  <matplotlib.lines.Line2D at 0x7faab7caddc0>,
#  <matplotlib.lines.Line2D at 0x7faab7cadd30>,
#  <matplotlib.lines.Line2D at 0x7faab7cad340>]

# %%
plt.plot(ins, cs)
plt.plot(ins, jnp.array(ds)*90)

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotting the RMSE and CRPS on the primary y-axis
color = 'tab:red'
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Divergence', color=color)
ln1 = ax1.plot(true_div, label='Divergence from True Solution', color='tab:orange', linestyle='-')
ax1.tick_params(axis='y', labelcolor=color)

# Create a twin y-axis for the inflation parameter
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Inflation', color=color)
ln3 = ax2.plot(inflations, label='Inflation Parameter', color=color, linestyle=':')
ax2.tick_params(axis='y', labelcolor=color)

# Combine legends from both axes
lns = ln1 + ln3
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='upper right')

plt.title('Inflation Parameter and Divergence from True Solution over Iterations')
plt.show()
